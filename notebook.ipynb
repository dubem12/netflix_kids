# %%
import pandas as pd
import numpy as np

# %%
df1= pd.read_csv('netflix_data_enhanced.csv')

# %%
df1.head()
# Out:
#                                  Title                              Cleaned  \
# 0            The Night Agent: Season 1                      The Night Agent
# 1            Ginny & Georgia: Season 2                      Ginny & Georgia
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                            The Glory
# 3                  Wednesday: Season 1                            Wednesday
# 4  Queen Charlotte: A Bridgerton Story  Queen Charlotte: A Bridgerton Story
#
#   Global        Date        Hours                                     URL  \
# 0    Yes     3/23/23  812,100,000  https://www.netflix.com/title/81450827
# 1    Yes  01/05/2023  665,100,000  https://www.netflix.com/title/81025696
# 2    Yes    12/30/22  622,800,000  https://www.netflix.com/title/81519223
# 3    Yes    11/23/22  507,700,000  https://www.netflix.com/title/81231974
# 4    Yes  05/04/2023  503,000,000  https://www.netflix.com/title/81476183
#
#                  Duration      Genre  \
# ...

# %%
df1.shape
# Out:
# (18214, 14)

# %%
excel_file_path = "What_We_Watched_A_Netflix_Engagement_Report_2023Jan-Jun.xlsx"
df2= pd.read_excel(excel_file_path)

df2.head()
# Out:
#    Unnamed: 0                                Title Available Globally?  \
# 0         NaN            The Night Agent: Season 1                 Yes
# 1         NaN            Ginny & Georgia: Season 2                 Yes
# 2         NaN   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes
# 3         NaN                  Wednesday: Season 1                 Yes
# 4         NaN  Queen Charlotte: A Bridgerton Story                 Yes
#
#   Release Date  Hours Viewed
# 0   2023-03-23     812100000
# 1   2023-01-05     665100000
# 2   2022-12-30     622800000
# 3   2022-11-23     507700000
# 4   2023-05-04     503000000

# %%
df2= df2.drop(df2.columns[0], axis=1)

# %%
df2.head()
# Out:
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#    Hours Viewed
# 0     812100000
# 1     665100000
# 2     622800000
# 3     507700000
# 4     503000000

# %%
df1['Genre'].unique()
# Out:
# array(['Thrillers', 'Drama', 'Fantasy', 'Action', 'Reality TV',
#        'Comedies', nan, 'Kids', 'Sci-Fi', 'Romance', 'Documentaries',
#        'Horror', 'Anime', 'Westerns', 'Musicals',
#        'TV Variety & Talk Shows', 'Music Non-Fiction', 'Special Interest',
#        'Sports Non-Fiction'], dtype=object)

# %%
#see shows with only kids
df_kids= df1[df1['Genre'] =='Kids']

df_kids.shape
# Out:
# (1200, 14)

# %%
df_nan = df1[pd.isna(df1["Genre"])]
df_nan.shape
# Out:
# (10391, 14)

# %%
df_nan.head()
# Out:
#                                                 Title  \
# 28                                         You People
# 34         Pablo Escobar, el patrón del mal: Season 1
# 37                                 Chiquititas (2013)
# 43  Til Money Do Us Part: Season 1 // Hasta que la...
# 55                        The Walking Dead: Season 11
#
#                               Cleaned Global      Date        Hours  URL  \
# 28                         You People    Yes   1/27/23  181,800,000  NaN
# 34  Pablo Escobar, el patr√≥n del mal    Yes       NaN  170,100,000  NaN
# 37                 Chiquititas (2013)     No       NaN  162,000,000  NaN
# 43               Til Money Do Us Part     No  10/19/22  152,100,000  NaN
# 55                   The Walking Dead     No       NaN  136,800,000  NaN
#
#    Duration Genre Genres Tags Plot Starring Creators Cast
# 28      NaN   NaN    NaN  NaN  NaN      NaN      NaN  NaN
# 34      NaN   NaN    NaN  NaN  NaN      NaN      NaN  NaN
# ...

# %%
df_kids.isna().sum()
# Out:
# Title         0
# Cleaned       0
# Global        0
# Date        571
# Hours         0
# URL           1
# Duration     23
# Genre         0
# Genres        0
# Tags          1
# Plot          2
# Starring     59
# Creators    741
# Cast          1
# dtype: int64

# %%
#sample with creators , so we can create a chart where we consider the durations and creators
column_to_drop = 'Creators'
df_kids2= df_kids.dropna (subset=[column_to_drop])

df_kids2= df_kids2.reset_index(drop=True)

# %%
df_kids= df_kids.reset_index(drop=True)

# %%
df_kids
# Out:
#                                                 Title  \
# 0                                PAW Patrol: Season 6
# 1                                 CoComelon: Season 1
# 2                                 CoComelon: Season 2
# 3                                 CoComelon: Season 3
# 4                                 CoComelon: Season 4
# ...                                               ...
# 1195               VeggieTales in the House: Season 4
# 1196                  Waffles + Mochi's Holiday Feast
# 1197  Wake Up: Season 1 // 麻醉風暴: 第 1 季 // 麻醉风暴: 第 1 季
# 1198  Wake Up: Season 2 // 麻醉風暴: 第 2 季 // 麻醉风暴: 第 2 季
# 1199               We Can Be Heroes // Bäst i Sverige
#
#                               Cleaned Global      Date        Hours  \
# 0                          PAW Patrol     No       NaN  149,300,000
# 1                           CoComelon     No   5/31/20  136,200,000
# 2                           CoComelon     No  12/17/20  102,300,000
# ...

# %%
#export df as excel
df_kids.to_excel('working_data/kids_df.xlsx')

# %%
df1.to_excel('working_data/enhanced.xlsx')
df2.to_excel('working_data/netflix_data.xlsx')
